# %% [markdown]
# # CMIC-DRC Workshop - Creating Processing Pipelines Using Nipype
#
# ## Example PET SUVR analysis workflow
#
# Will Coath, 12th March 2021

# %% [markdown]
# ## Overview
#
# We have 5 participants with T1-weighted MRI and amyloid-PET (florbetapir/AV45) images. We want to compute a standard uptake value ratio (SUVR) for these participants. To calculate SUVR we will divide the PET tracer retention in a cortical region of interest by the retention in the cerebellum.
#
# We will construct a pipeline using many common software packages.
#
# This is a workflow to demonstrate some of the basic aspects of Nipype, not necessarily the optimal analysis pipeline.
#
# 1. Co-register the 55-60 min PET frame to the 50-55 min frame and average them (FSL FLIRT and fslmaths)
# 2. Smooth PET wtih 6mm FWHM kernel (SPM)
# 3. Co-register MRI to MNI template (FSL FLIRT)
# 4. Co-register the PET to the MRI (NiftyReg)
# 5. Spatially normalise to MNI space template, then apply parameters to PET (SPM)
# 6. Normalise the PET uptake to cerebellum region (fslmaths)
# 7. Extract SUVR from cortical region (fslstats)

# %% [markdown]
# ## Setting some parameters
#
# Setting these at the top makes it easy to make changes later.

# %%
# Set some paths
experiment_dir = '/home/neuro/output'
data_dir = '/home/neuro/data/oasis_dataset'
result_dir='/home/neuro/output/results'
working_dir = '/home/neuro/output/working'

# list of subject ids
#subject_list = ['sub-OAS30001','sub-OAS30002','sub-OAS30003','sub-OAS30004','sub-OAS30005']


#just run on two for now
subject_list = ['sub-OAS30001','sub-OAS30002']

# Smoothing widths used during preprocessing of PET
fwhm = [6,6,6]

# Template to normalize to
template = '/home/neuro/data/avg152T1.nii'

# Cerebellum reference mask in MNI space
cereb_mask = '/home/neuro/data/voi_WhlCbl_2mm.nii'

# Cortical target region mask in MNI space
ctx_mask = '/home/neuro/data/voi_ctx_2mm.nii'

# %% [markdown]
# ## Interfaces link to software packages
#
# Nipype has interfaces with many common neuroimaging packages.
#
# Let's import some interfaces we will use.

# %%
#import modules
from nipype.interfaces import fsl # FSL interfaces 
from nipype.interfaces import spm  # SPM interfaces
from nipype.interfaces import niftyreg # NiftyReg
from nipype.algorithms.misc import Gunzip # Gunzip
import nipype.interfaces.utility as util  # utility, for IdentityInterface and Function

# %% [markdown]
# ## Interfaces go inside Nodes
#
# We can package up specific instances of interfaces in Nodes, this makes them compatable with a pipeline.

# %%
import nipype.pipeline.engine as pe  # for Workflow and Node wrappers

### NODES TO PREPROCESS THE PET ###

# co-register last frame (55-60mins) to first (50-55mins) 
# tell FSL to save output as '.nii', as SPM won't accept '.nii.gz'
coreg_frames = pe.Node(interface=fsl.FLIRT(cost_func='normcorr',
                                        dof=6,
                                        output_type = "NIFTI"),
                    name='flt_coreg_frames')


# add frames together, takes in_file and operand_file and adds them
add_frames = pe.Node(fsl.BinaryMaths(operation='add',
                                     output_type = "NIFTI"),
                         name='fmaths_add_frames')

# divide by 2 to make 50-60min average frame
div_frames = pe.Node(fsl.BinaryMaths(operation='div',
                                     operand_value=2,
                                     output_type = "NIFTI"),
                         name='fmaths_div_frames')

# Node containing spm interface to smooth the 50-60 PET image by 6mm fwhm 
smooth = pe.Node(interface=spm.Smooth(fwhm=fwhm), 
                   name='spm_smooth')

# %% [markdown]
# ## Connecting nodes together in a Workflow
#
# Here we start a Workflow to connect the Nodes together, we take outputs from one Node and pass them to another.
#
# You can find out what the input and output of certain interfaces are called here:

# %%
suvr_pipeline = pe.Workflow(name='suvr')

suvr_pipeline.base_dir = working_dir

suvr_pipeline.connect([
    # give co-registered second frame from fslmaths output to sum
    # then to divide by 2
    (coreg_frames, add_frames, [('out_file', 'operand_file')]),
    (add_frames, div_frames, [('out_file', 'in_file')]),
    (div_frames, smooth, [('out_file', 'in_files')]),
])

# %% [markdown]
# ## More nodes...
#
# Next, we will create some Nodes to spatially normalise the PET using SPM normalise.

# %%
coreg_template = pe.Node(interface=fsl.FLIRT(cost_func='mutualinfo',
                                             reference=template,
                                             dof=6,
                                             output_type = "NIFTI"),
                    name='flt_coreg_template')

coreg_petmr = pe.Node(interface=niftyreg.RegAladin(rig_only_flag=True),
                    name='aladin_coreg_petmr')

# bounding box needs to be set to NaN in SPM, create nan float variable
n=float("nan")

# spatially normalise the T1 to the MNI template - Estimate & Write (estwrite) mode is the default
norm_anat = pe.Node(interface=spm.Normalize(template=template,
                                            write_bounding_box=[[n, n, n], [n, n, n]]),
                    name='spm_norm_anat')

# to apply the non-linear transform from 'norm_anat' to the PET (write only mode)
norm_pet = pe.Node(interface=spm.Normalize(jobtype='write',
                                          write_bounding_box=[[n, n, n], [n, n, n]]),
                    name='spm_norm_pet')

# node to unzip the PET file before SPM step, as RegAladin has saved resampled PET file as '.nii.gz'
gunzip_pet = pe.Node(Gunzip(),
                name='gunzip_pet')

# %% [markdown]
# And we can connect these to the same pipeline

# %%
suvr_pipeline.connect([
    # pass PET from smoothing to niftyReg
    (smooth, coreg_petmr, [('smoothed_files', 'flo_file')]),
    (coreg_template, coreg_petmr, [('out_file', 'ref_file')]),
    (coreg_template, norm_anat, [('out_file', 'source')]),
    (coreg_petmr, gunzip_pet, [('res_file', 'in_file')]),
    (gunzip_pet, norm_pet, [('out_file', 'apply_to_files')]),
    (norm_anat, norm_pet, [('normalization_parameters', 'parameter_file')]),
])

# %% [markdown]
# ## ...and speficy some more nodes...and connect them to the pipeline
#
# To calculate SUVR and extract mean values.

# %%
# extract reference region mean raw uptake
ref_uptake = pe.Node(fsl.ImageStats(mask_file=cereb_mask,
                                   op_string='-k %s -M'),
                name='fstats_ref_uptake')

# extract target region mean raw uptake (just for possible use later in models)
tar_uptake = pe.Node(fsl.ImageStats(mask_file=ctx_mask,
                                   op_string='-k %s -M'),
                name='fstats_tar_uptake')

# create SUVR image by dividing PET MNI image by result of ref_uptake
suvr_img = pe.Node(fsl.BinaryMaths(operation='div',
                                     output_type = "NIFTI_GZ"),
                name='fmaths_suvr_img')

#extract mean SUVR value from target region
tar_suvr = pe.Node(fsl.ImageStats(mask_file=ctx_mask,
                                   op_string='-k %s -M'),
                name='fstats_tar_suvr')

suvr_pipeline.connect([
    # connect PET in MNI space to fslstats to get reference mean uptake
    (norm_pet, ref_uptake, [('normalized_files', 'in_file')]),
    # connect PET in MNI space to fslstats to get target mean uptake
    (norm_pet, tar_uptake, [('normalized_files', 'in_file')]),
    # give MNI PET to fslmaths to calculate SUVR
    (norm_pet, suvr_img, [('normalized_files', 'in_file')]),
    # give output stat, the mean of cerebellum uptake, to fslmaths to 
    # divide the pet image by it
    (ref_uptake, suvr_img, [('out_stat', 'operand_value')]),
    # give SUVR image to 
    (suvr_img, tar_suvr, [('out_file', 'in_file')]),
])

# %% [markdown]
# ## Creating our own function
#
# If you need to do anything else you can define a function and wrap it inside a Node.

# %%
#create custom function for writing output to csv file
def OutCSV(ref_uptake,tar_uptake,tar_suvr):
    #note we need to import python modules within the function, as environment is separate
    import os 
    header = "reference_uptake,target_uptake,target_suvr \n"
    row = str(ref_uptake) + ',' + str(tar_uptake) + ',' + str(tar_suvr)
    
    file_name = 'result.csv'
    
    with open(file_name, 'w') as fp:
        fp.write(header)
        fp.write(row)
    return os.path.abspath(file_name)

# %% [markdown]
# Then we need to package our function inside a Node, in order to connect it to the Workflow

# %%
#define Node with our function inside to put it into our workflow
get_csv = pe.Node(util.Function(input_names=['ref_uptake','tar_uptake', 'tar_suvr'],
                                output_names=['result_file'],
                                function=OutCSV),
                  name='get_csv')


suvr_pipeline.connect([
    (ref_uptake, get_csv, [('out_stat', 'ref_uptake')]),
    (tar_uptake, get_csv, [('out_stat', 'tar_uptake')]),
    (tar_suvr, get_csv, [('out_stat', 'tar_suvr')]), 
])

# %% [markdown]
# ## Grab input data
#
# Hang on a minute...how do the Nodes know how to find our scans?
#
# We create a node called 'infosource' containing the 'IdentityInterface', this iterates over our subject list (specified at the top) and feeds them into the 'datasource' Node, containing a 'DataGrabber' interface. The DataGrabber uses a template and fills in the subject ids provided to pick up the scans we want.
#
# The 'info' variable is a dictionary that links each id with both PET frames and the T1 image. The DataGrabber then uses a template to construct paths to each image.

# %%
import nipype.interfaces.io as nio  # Data input and output, DataGrabber and DataSink

infosource = pe.Node(
    interface=util.IdentityInterface(fields=['subject_id']),
    name="infosource")

infosource.iterables = ('subject_id', subject_list)

# Map field names to individual subject runs.
info = dict(
    pet1=[['subject_id','pet','t50-55']],
    pet2=[['subject_id','pet','t55-60']],
    anat=[['subject_id', 'anat','T1w']])

datasource = pe.Node(interface=nio.DataGrabber(infields=['subject_id'], 
                                               outfields=['pet1', 'pet2','anat']),
                     name='datasource')

datasource.inputs.base_directory = data_dir
datasource.inputs.template = '%s/ses-test/%s/*%s*.nii.gz'
datasource.inputs.template_args = info
datasource.inputs.sort_filelist = True

# %% [markdown]
# ## Connect inputs to SUVR Workflow

# %%
suvr_pipeline.connect([
    # connect subject id list to DataGrabber
    (infosource, datasource, [('subject_id', 'subject_id')]),
    # give both PET frames (pet1 and pet2) to FLIRT to co-register second frame to first 
    (datasource, coreg_frames, [('pet2', 'in_file'),
                               ('pet1','reference')]),
    # give first pet frame to fslmaths 
    (datasource, add_frames, [('pet1', 'in_file')]),
    # pass T1 MRI to node to co-reg with template
    (datasource, coreg_template, [('anat', 'in_file')]), 
])

# %% [markdown]
# ## Store the output we want
#
# DataSink interface

# %%
datasink = pe.Node(interface=nio.DataSink(), name="datasink")

datasink.inputs.base_directory = experiment_dir
datasink.inputs.container = result_dir

## Define substitution strings
substitutions = [('_subject_id_', ''),
                 ('wssub-','mni_smoothed_sub-'),
                 ("_t50-55_maths_maths", "_t50-60-avg"),
                 ('ssub-', 'smoothed_sub-'),
                 ('avg_res_maths.nii','avg_suvr.nii')
                ]

## Feed the substitution strings to the DataSink node
datasink.inputs.substitutions = substitutions

suvr_pipeline.connect([
    #connect the list of participants to datasink to make separate containers for each
    #(infosource, datasink, [('subject_id', 'container')]),
    #save output from PET frame co-reg in datasink
    (coreg_frames, datasink, [('out_file', 'coreg_frames'),
                             ('out_matrix_file', 'coreg_frames.@xfm')]),
    #save average 50-60min frame image in the datasink
    (div_frames, datasink, [('out_file', 'pet_t5060')]),
    #save smoothed average 50-60min frame
    (smooth, datasink, [('smoothed_files', 'pet_t5060.@smoothed')]),
    #save PET file that has been co-registered to the MRI
    (coreg_petmr, datasink, [('res_file', 'coreg_pet-t1')]),
    #and save the PET to T1 transformation matrix in xfm sub dir
    (coreg_petmr, datasink, [('aff_file', 'coreg_pet-t1.@xfm')]),
    #save spatially normalised T1 image to anat_mni 
    (norm_anat, datasink, [('normalized_source', 't1_mni')]),
    # and save normalisation parameters to sub directory
    (norm_anat, datasink, [('normalization_parameters', 't1_mni.@xfm')]),
    #save spatially normalised PET image to pet_mni
    (norm_pet, datasink, [('normalized_files', 'pet_mni')]),
    #add suvr image to datasink
    (suvr_img, datasink, [('out_file','suvr_result')]),
    (get_csv, datasink, [('result_file','suvr_result.@csv')]),
])

# %% [markdown]
# ## Run Workflow and print graph

# %%
suvr_pipeline.run(plugin='MultiProc') #run in parallel
suvr_pipeline.write_graph(dotfilename='/home/neuro/output/results/workflow_graph.dot')
# Out:
# 210311-11:13:44,822 nipype.workflow INFO:
# 	 Workflow suvr settings: ['check', 'execution', 'logging', 'monitoring']
# 210311-11:13:45,27 nipype.workflow INFO:
# 	 Running in parallel.
# 210311-11:13:45,62 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:13:45,207 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasource" in "/home/neuro/suvr/_subject_id_sub-OAS30005/datasource".
# 210311-11:13:45,209 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasource" in "/home/neuro/suvr/_subject_id_sub-OAS30004/datasource".210311-11:13:45,244 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
#
# 210311-11:13:45,284 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 210311-11:13:45,406 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasource".
# 210311-11:13:45,420 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasource".
# 210311-11:13:47,58 nipype.workflow INFO:
# 	 [Job 0] Completed (suvr.datasource).
# 210311-11:13:47,63 nipype.workflow INFO:
# 	 [Job 16] Completed (suvr.datasource).
# 210311-11:13:47,69 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:13:47,159 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.flt_coreg_template" in "/home/neuro/suvr/_subject_id_sub-OAS30005/flt_coreg_template".
# 210311-11:13:47,161 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.flt_coreg_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30005/flt_coreg_frames".
# 210311-11:13:47,232 nipype.workflow INFO:
# 	 [Node] Running "flt_coreg_template" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/data/oasis_dataset/sub-OAS30005/ses-test/anat/sub-OAS30005_ses-test_T1w.nii.gz -ref /home/neuro/data/avg152T1.nii -out sub-OAS30005_ses-test_T1w_flirt.nii -omat sub-OAS30005_ses-test_T1w_flirt.mat -searchcost mutualinfo -dof 6
# 210311-11:13:47,234 nipype.workflow INFO:
# 	 [Node] Running "flt_coreg_frames" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/data/oasis_dataset/sub-OAS30005/ses-test/pet/sub-OAS30005_ses-test_acq-AV45_pet_t55-60.nii.gz -ref /home/neuro/data/oasis_dataset/sub-OAS30005/ses-test/pet/sub-OAS30005_ses-test_acq-AV45_pet_t50-55.nii.gz -out sub-OAS30005_ses-test_acq-AV45_pet_t55-60_flirt.nii -omat sub-OAS30005_ses-test_acq-AV45_pet_t55-60_flirt.mat -searchcost normcorr -dof 6
# 210311-11:13:49,59 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
#                        * suvr.flt_coreg_template
# 210311-11:16:04,27 nipype.workflow INFO:
# 	 [Node] Finished "suvr.flt_coreg_template".
# 210311-11:16:05,256 nipype.workflow INFO:
# 	 [Job 1] Completed (suvr.flt_coreg_template).
# 210311-11:16:05,288 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:16:05,421 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_anat" in "/home/neuro/suvr/_subject_id_sub-OAS30005/spm_norm_anat".
# 210311-11:16:05,522 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_anat" ("nipype.interfaces.spm.preprocess.Normalize")
# 210311-11:16:07,259 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
#                        * suvr.flt_coreg_frames
# 210311-11:16:26,141 nipype.workflow INFO:
# 	 [Node] Finished "suvr.flt_coreg_frames".
# 210311-11:16:27,399 nipype.workflow INFO:
# 	 [Job 3] Completed (suvr.flt_coreg_frames).
# 210311-11:16:27,407 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:16:27,489 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_add_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_add_frames".
# 210311-11:16:27,540 nipype.workflow INFO:
# 	 [Node] Running "fmaths_add_frames" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/data/oasis_dataset/sub-OAS30005/ses-test/pet/sub-OAS30005_ses-test_acq-AV45_pet_t50-55.nii.gz -add /home/neuro/suvr/_subject_id_sub-OAS30005/flt_coreg_frames/sub-OAS30005_ses-test_acq-AV45_pet_t55-60_flirt.nii /home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_add_frames/sub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths.nii
# 210311-11:16:28,377 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_add_frames".
# 210311-11:16:29,366 nipype.workflow INFO:
# 	 [Job 4] Completed (suvr.fmaths_add_frames).
# 210311-11:16:29,382 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:16:29,468 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_div_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_div_frames".
# 210311-11:16:29,503 nipype.workflow INFO:
# 	 [Node] Running "fmaths_div_frames" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_add_frames/sub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths.nii -div 2.00000000 /home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_div_frames/sub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths.nii
# 210311-11:16:29,900 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_div_frames".
# 210311-11:16:31,380 nipype.workflow INFO:
# 	 [Job 5] Completed (suvr.fmaths_div_frames).
# 210311-11:16:31,392 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:16:31,532 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_smooth" in "/home/neuro/suvr/_subject_id_sub-OAS30005/spm_smooth".
# 210311-11:16:31,617 nipype.workflow INFO:
# 	 [Node] Running "spm_smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 210311-11:16:33,371 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_smooth
#                        * suvr.spm_norm_anat
# 210311-11:16:50,707 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_anat".
# 210311-11:16:51,390 nipype.workflow INFO:
# 	 [Job 2] Completed (suvr.spm_norm_anat).
# 210311-11:16:51,401 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_smooth
# 210311-11:16:51,487 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.flt_coreg_template" in "/home/neuro/suvr/_subject_id_sub-OAS30004/flt_coreg_template".
# 210311-11:16:51,517 nipype.workflow INFO:
# 	 [Node] Running "flt_coreg_template" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/data/oasis_dataset/sub-OAS30004/ses-test/anat/sub-OAS30004_ses-test_T1w.nii.gz -ref /home/neuro/data/avg152T1.nii -out sub-OAS30004_ses-test_T1w_flirt.nii -omat sub-OAS30004_ses-test_T1w_flirt.mat -searchcost mutualinfo -dof 6
# 210311-11:16:53,398 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
#                        * suvr.spm_smooth
# 210311-11:16:54,130 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_smooth".
# 210311-11:16:55,410 nipype.workflow INFO:
# 	 [Job 6] Completed (suvr.spm_smooth).
# 210311-11:16:55,458 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:16:55,725 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.aladin_coreg_petmr" in "/home/neuro/suvr/_subject_id_sub-OAS30005/aladin_coreg_petmr".
# 210311-11:16:55,795 nipype.workflow INFO:
# 	 [Node] Running "aladin_coreg_petmr" ("nipype.interfaces.niftyreg.reg.RegAladin"), a CommandLine Interface with command:
# reg_aladin -aff ssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -flo /home/neuro/suvr/_subject_id_sub-OAS30005/spm_smooth/ssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -omp 1 -ref /home/neuro/suvr/_subject_id_sub-OAS30005/flt_coreg_template/sub-OAS30005_ses-test_T1w_flirt.nii -res ssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -rigOnly
# 210311-11:16:57,443 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.aladin_coreg_petmr
#                        * suvr.flt_coreg_template
# 210311-11:19:28,961 nipype.workflow INFO:
# 	 [Node] Finished "suvr.aladin_coreg_petmr".
# 210311-11:19:29,839 nipype.workflow INFO:
# 	 [Job 7] Completed (suvr.aladin_coreg_petmr).
# 210311-11:19:29,857 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:19:29,926 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.gunzip_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30005/gunzip_pet".
# 210311-11:19:29,943 nipype.workflow INFO:
# 	 [Node] Running "gunzip_pet" ("nipype.algorithms.misc.Gunzip")
# 210311-11:19:30,35 nipype.workflow INFO:
# 	 [Node] Finished "suvr.gunzip_pet".
# 210311-11:19:31,846 nipype.workflow INFO:
# 	 [Job 8] Completed (suvr.gunzip_pet).
# 210311-11:19:31,857 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:19:31,953 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30005/spm_norm_pet".
# 210311-11:19:32,25 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_pet" ("nipype.interfaces.spm.preprocess.Normalize")
# 210311-11:19:33,859 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_norm_pet
#                        * suvr.flt_coreg_template
# 210311-11:19:58,470 nipype.workflow INFO:
# 	 [Node] Finished "suvr.flt_coreg_template".
# 210311-11:19:59,850 nipype.workflow INFO:
# 	 [Job 17] Completed (suvr.flt_coreg_template).
# 210311-11:19:59,859 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_pet
# 210311-11:19:59,959 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_anat" in "/home/neuro/suvr/_subject_id_sub-OAS30004/spm_norm_anat".
# 210311-11:20:00,34 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_anat" ("nipype.interfaces.spm.preprocess.Normalize")210311-11:20:00,50 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_pet".
#
# 210311-11:20:01,852 nipype.workflow INFO:
# 	 [Job 9] Completed (suvr.spm_norm_pet).
# 210311-11:20:01,861 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 6 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:20:01,922 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_tar_uptake" in "/home/neuro/suvr/_subject_id_sub-OAS30005/fstats_tar_uptake".
# 210311-11:20:01,945 nipype.workflow INFO:
# 	 [Node] Running "fstats_tar_uptake" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30005/spm_norm_pet/wssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -k /home/neuro/data/voi_ctx_2mm.nii -M
# 210311-11:20:02,251 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_tar_uptake".
# 210311-11:20:03,853 nipype.workflow INFO:
# 	 [Job 10] Completed (suvr.fstats_tar_uptake).
# 210311-11:20:03,864 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:20:03,925 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_ref_uptake" in "/home/neuro/suvr/_subject_id_sub-OAS30005/fstats_ref_uptake".
# 210311-11:20:03,951 nipype.workflow INFO:
# 	 [Node] Running "fstats_ref_uptake" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30005/spm_norm_pet/wssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -k /home/neuro/data/voi_WhlCbl_2mm.nii -M
# 210311-11:20:04,309 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_ref_uptake".
# 210311-11:20:05,856 nipype.workflow INFO:
# 	 [Job 11] Completed (suvr.fstats_ref_uptake).
# 210311-11:20:05,879 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:20:06,7 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_suvr_img" in "/home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_suvr_img".
# 210311-11:20:06,51 nipype.workflow INFO:
# 	 [Node] Running "fmaths_suvr_img" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/suvr/_subject_id_sub-OAS30005/spm_norm_pet/wssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -div 5480.44671600 /home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_suvr_img/wssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz
# 210311-11:20:07,858 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.fmaths_suvr_img
#                        * suvr.spm_norm_anat
# 210311-11:20:07,878 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_suvr_img".
# 210311-11:20:09,863 nipype.workflow INFO:
# 	 [Job 12] Completed (suvr.fmaths_suvr_img).
# 210311-11:20:09,873 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:20:09,967 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_tar_suvr" in "/home/neuro/suvr/_subject_id_sub-OAS30005/fstats_tar_suvr".
# 210311-11:20:10,13 nipype.workflow INFO:
# 	 [Node] Running "fstats_tar_suvr" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30005/fmaths_suvr_img/wssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -k /home/neuro/data/voi_ctx_2mm.nii -M
# 210311-11:20:10,633 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_tar_suvr".
# 210311-11:20:11,867 nipype.workflow INFO:
# 	 [Job 13] Completed (suvr.fstats_tar_suvr).
# 210311-11:20:11,884 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:20:12,84 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.get_csv" in "/home/neuro/suvr/_subject_id_sub-OAS30005/get_csv".
# 210311-11:20:12,134 nipype.workflow INFO:
# 	 [Node] Running "get_csv" ("nipype.interfaces.utility.wrappers.Function")
# 210311-11:20:12,199 nipype.workflow INFO:
# 	 [Node] Finished "suvr.get_csv".
# 210311-11:20:13,869 nipype.workflow INFO:
# 	 [Job 14] Completed (suvr.get_csv).
# 210311-11:20:13,886 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:20:14,102 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasink" in "/home/neuro/suvr/_subject_id_sub-OAS30005/datasink".
# 210311-11:20:14,211 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210311-11:20:14,242 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30005/sub-OAS30005_ses-test_acq-AV45_pet_t55-60_flirt.nii -> /home/neuro/coreg_frames/sub-OAS30005/sub-OAS30005_ses-test_acq-AV45_pet_t55-60_flirt.nii
# 210311-11:20:14,285 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30005/sub-OAS30005_ses-test_acq-AV45_pet_t55-60_flirt.mat -> /home/neuro/coreg_frames/sub-OAS30005/sub-OAS30005_ses-test_acq-AV45_pet_t55-60_flirt.mat
# 210311-11:20:14,341 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30005/sub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30005/sub-OAS30005_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:20:14,385 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30005/ssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30005/smoothed_sub-OAS30005_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:20:14,467 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30005/ssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -> /home/neuro/coreg_pet-t1/sub-OAS30005/smoothed_sub-OAS30005_ses-test_acq-AV45_pet_t50-60-avg_res.nii.gz
# 210311-11:20:14,550 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30005/ssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -> /home/neuro/coreg_pet-t1/sub-OAS30005/smoothed_sub-OAS30005_ses-test_acq-AV45_pet_t50-60-avg_aff.txt
# 210311-11:20:14,601 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30005/wsub-OAS30005_ses-test_T1w_flirt.nii -> /home/neuro/t1_mni/sub-OAS30005/wsub-OAS30005_ses-test_T1w_flirt.nii
# 210311-11:20:14,651 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30005/sub-OAS30005_ses-test_T1w_flirt_sn.mat -> /home/neuro/t1_mni/sub-OAS30005/sub-OAS30005_ses-test_T1w_flirt_sn.mat
# 210311-11:20:14,729 nipype.interface INFO:
# 	 sub: /home/neuro/pet_mni/_subject_id_sub-OAS30005/wssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -> /home/neuro/pet_mni/sub-OAS30005/mni_smoothed_sub-OAS30005_ses-test_acq-AV45_pet_t50-60-avg_res.nii
# 210311-11:20:14,766 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30005/wssub-OAS30005_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -> /home/neuro/suvr_result/sub-OAS30005/mni_smoothed_sub-OAS30005_ses-test_acq-AV45_pet_t50-60-avg_suvr.nii.gz
# 210311-11:20:14,806 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30005/result.csv -> /home/neuro/suvr_result/sub-OAS30005/result.csv
# 210311-11:20:14,909 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasink".
# 210311-11:20:15,874 nipype.workflow INFO:
# 	 [Job 15] Completed (suvr.datasink).
# 210311-11:20:15,904 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:20:16,91 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.flt_coreg_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30004/flt_coreg_frames".
# 210311-11:20:16,173 nipype.workflow INFO:
# 	 [Node] Running "flt_coreg_frames" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/data/oasis_dataset/sub-OAS30004/ses-test/pet/sub-OAS30004_ses-test_acq-AV45_pet_t55-60.nii.gz -ref /home/neuro/data/oasis_dataset/sub-OAS30004/ses-test/pet/sub-OAS30004_ses-test_acq-AV45_pet_t50-55.nii.gz -out sub-OAS30004_ses-test_acq-AV45_pet_t55-60_flirt.nii -omat sub-OAS30004_ses-test_acq-AV45_pet_t55-60_flirt.mat -searchcost normcorr -dof 6
# 210311-11:20:17,905 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
#                        * suvr.spm_norm_anat
# 210311-11:21:09,262 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_anat".
# 210311-11:21:10,354 nipype.workflow INFO:
# 	 [Job 18] Completed (suvr.spm_norm_anat).
# 210311-11:21:10,361 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:21:10,464 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasource" in "/home/neuro/suvr/_subject_id_sub-OAS30003/datasource".
# 210311-11:21:10,534 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 210311-11:21:10,622 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasource".
# 210311-11:21:12,354 nipype.workflow INFO:
# 	 [Job 32] Completed (suvr.datasource).
# 210311-11:21:12,365 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:21:12,527 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.flt_coreg_template" in "/home/neuro/suvr/_subject_id_sub-OAS30003/flt_coreg_template".
# 210311-11:21:12,557 nipype.workflow INFO:
# 	 [Node] Running "flt_coreg_template" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/data/oasis_dataset/sub-OAS30003/ses-test/anat/sub-OAS30003_ses-test_T1w.nii.gz -ref /home/neuro/data/avg152T1.nii -out sub-OAS30003_ses-test_T1w_flirt.nii -omat sub-OAS30003_ses-test_T1w_flirt.mat -searchcost mutualinfo -dof 6
# 210311-11:21:14,357 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
#                        * suvr.flt_coreg_frames
# 210311-11:23:07,587 nipype.workflow INFO:
# 	 [Node] Finished "suvr.flt_coreg_frames".
# 210311-11:23:08,516 nipype.workflow INFO:
# 	 [Job 19] Completed (suvr.flt_coreg_frames).
# 210311-11:23:08,532 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:23:08,818 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_add_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_add_frames".
# 210311-11:23:08,896 nipype.workflow INFO:
# 	 [Node] Running "fmaths_add_frames" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/data/oasis_dataset/sub-OAS30004/ses-test/pet/sub-OAS30004_ses-test_acq-AV45_pet_t50-55.nii.gz -add /home/neuro/suvr/_subject_id_sub-OAS30004/flt_coreg_frames/sub-OAS30004_ses-test_acq-AV45_pet_t55-60_flirt.nii /home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_add_frames/sub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths.nii
# 210311-11:23:10,562 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.fmaths_add_frames
#                        * suvr.flt_coreg_template
# 210311-11:23:11,483 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_add_frames".
# 210311-11:23:12,673 nipype.workflow INFO:
# 	 [Job 20] Completed (suvr.fmaths_add_frames).
# 210311-11:23:12,720 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:23:12,991 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_div_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_div_frames".
# 210311-11:23:13,524 nipype.workflow INFO:
# 	 [Node] Running "fmaths_div_frames" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_add_frames/sub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths.nii -div 2.00000000 /home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_div_frames/sub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths.nii
# 210311-11:23:14,651 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.fmaths_div_frames
#                        * suvr.flt_coreg_template
# 210311-11:23:15,516 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_div_frames".
# 210311-11:23:16,676 nipype.workflow INFO:
# 	 [Job 21] Completed (suvr.fmaths_div_frames).
# 210311-11:23:16,740 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:23:16,921 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_smooth" in "/home/neuro/suvr/_subject_id_sub-OAS30004/spm_smooth".
# 210311-11:23:17,39 nipype.workflow INFO:
# 	 [Node] Running "spm_smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 210311-11:23:18,697 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_smooth
#                        * suvr.flt_coreg_template
# 210311-11:23:48,636 nipype.workflow INFO:
# 	 [Node] Finished "suvr.flt_coreg_template".
# 210311-11:23:48,728 nipype.workflow INFO:
# 	 [Job 33] Completed (suvr.flt_coreg_template).
# 210311-11:23:48,767 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_smooth
# 210311-11:23:48,964 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_anat" in "/home/neuro/suvr/_subject_id_sub-OAS30003/spm_norm_anat".
# 210311-11:23:49,131 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_anat" ("nipype.interfaces.spm.preprocess.Normalize")
# 210311-11:23:50,689 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
#                        * suvr.spm_smooth
# 210311-11:23:59,207 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_smooth".
# 210311-11:24:00,664 nipype.workflow INFO:
# 	 [Job 22] Completed (suvr.spm_smooth).
# 210311-11:24:00,688 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:24:00,812 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.aladin_coreg_petmr" in "/home/neuro/suvr/_subject_id_sub-OAS30004/aladin_coreg_petmr".
# 210311-11:24:00,858 nipype.workflow INFO:
# 	 [Node] Running "aladin_coreg_petmr" ("nipype.interfaces.niftyreg.reg.RegAladin"), a CommandLine Interface with command:
# reg_aladin -aff ssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -flo /home/neuro/suvr/_subject_id_sub-OAS30004/spm_smooth/ssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -omp 1 -ref /home/neuro/suvr/_subject_id_sub-OAS30004/flt_coreg_template/sub-OAS30004_ses-test_T1w_flirt.nii -res ssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -rigOnly
# 210311-11:24:02,682 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.aladin_coreg_petmr
#                        * suvr.spm_norm_anat
# 210311-11:24:30,381 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_anat".
# 210311-11:24:30,669 nipype.workflow INFO:
# 	 [Job 34] Completed (suvr.spm_norm_anat).
# 210311-11:24:30,681 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.aladin_coreg_petmr
# 210311-11:24:30,743 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.flt_coreg_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30003/flt_coreg_frames".
# 210311-11:24:30,775 nipype.workflow INFO:
# 	 [Node] Running "flt_coreg_frames" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/data/oasis_dataset/sub-OAS30003/ses-test/pet/sub-OAS30003_ses-test_acq-AV45_pet_t55-60.nii.gz -ref /home/neuro/data/oasis_dataset/sub-OAS30003/ses-test/pet/sub-OAS30003_ses-test_acq-AV45_pet_t50-55.nii.gz -out sub-OAS30003_ses-test_acq-AV45_pet_t55-60_flirt.nii -omat sub-OAS30003_ses-test_acq-AV45_pet_t55-60_flirt.mat -searchcost normcorr -dof 6
# 210311-11:24:32,675 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
#                        * suvr.aladin_coreg_petmr
# 210311-11:27:03,529 nipype.workflow INFO:
# 	 [Node] Finished "suvr.aladin_coreg_petmr".
# 210311-11:27:04,924 nipype.workflow INFO:
# 	 [Job 23] Completed (suvr.aladin_coreg_petmr).
# 210311-11:27:04,945 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:05,543 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.gunzip_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30004/gunzip_pet".
# 210311-11:27:05,627 nipype.workflow INFO:
# 	 [Node] Running "gunzip_pet" ("nipype.algorithms.misc.Gunzip")
# 210311-11:27:05,772 nipype.workflow INFO:
# 	 [Node] Finished "suvr.gunzip_pet".
# 210311-11:27:06,987 nipype.workflow INFO:
# 	 [Job 24] Completed (suvr.gunzip_pet).
# 210311-11:27:07,6 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:07,360 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30004/spm_norm_pet".
# 210311-11:27:07,590 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_pet" ("nipype.interfaces.spm.preprocess.Normalize")
# 210311-11:27:08,993 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_norm_pet
#                        * suvr.flt_coreg_frames
# 210311-11:27:40,389 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_pet".
# 210311-11:27:41,295 nipype.workflow INFO:
# 	 [Job 25] Completed (suvr.spm_norm_pet).
# 210311-11:27:41,313 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:41,409 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_tar_uptake" in "/home/neuro/suvr/_subject_id_sub-OAS30004/fstats_tar_uptake".
# 210311-11:27:41,508 nipype.workflow INFO:
# 	 [Node] Running "fstats_tar_uptake" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30004/spm_norm_pet/wssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -k /home/neuro/data/voi_ctx_2mm.nii -M
# 210311-11:27:41,996 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_tar_uptake".
# 210311-11:27:43,287 nipype.workflow INFO:
# 	 [Job 26] Completed (suvr.fstats_tar_uptake).
# 210311-11:27:43,300 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:43,407 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_ref_uptake" in "/home/neuro/suvr/_subject_id_sub-OAS30004/fstats_ref_uptake".
# 210311-11:27:43,444 nipype.workflow INFO:
# 	 [Node] Running "fstats_ref_uptake" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30004/spm_norm_pet/wssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -k /home/neuro/data/voi_WhlCbl_2mm.nii -M
# 210311-11:27:44,107 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_ref_uptake".
# 210311-11:27:45,292 nipype.workflow INFO:
# 	 [Job 27] Completed (suvr.fstats_ref_uptake).
# 210311-11:27:45,307 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:45,400 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_suvr_img" in "/home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_suvr_img".
# 210311-11:27:45,468 nipype.workflow INFO:
# 	 [Node] Running "fmaths_suvr_img" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/suvr/_subject_id_sub-OAS30004/spm_norm_pet/wssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -div 3644.36768700 /home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_suvr_img/wssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz
# 210311-11:27:46,913 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_suvr_img".
# 210311-11:27:47,295 nipype.workflow INFO:
# 	 [Job 28] Completed (suvr.fmaths_suvr_img).
# 210311-11:27:47,308 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:47,616 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_tar_suvr" in "/home/neuro/suvr/_subject_id_sub-OAS30004/fstats_tar_suvr".
# 210311-11:27:47,869 nipype.workflow INFO:
# 	 [Node] Running "fstats_tar_suvr" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30004/fmaths_suvr_img/wssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -k /home/neuro/data/voi_ctx_2mm.nii -M
# 210311-11:27:48,904 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_tar_suvr".
# 210311-11:27:49,296 nipype.workflow INFO:
# 	 [Job 29] Completed (suvr.fstats_tar_suvr).
# 210311-11:27:49,360 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:49,733 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.get_csv" in "/home/neuro/suvr/_subject_id_sub-OAS30004/get_csv".
# 210311-11:27:49,801 nipype.workflow INFO:
# 	 [Node] Running "get_csv" ("nipype.interfaces.utility.wrappers.Function")
# 210311-11:27:49,900 nipype.workflow INFO:
# 	 [Node] Finished "suvr.get_csv".
# 210311-11:27:51,297 nipype.workflow INFO:
# 	 [Job 30] Completed (suvr.get_csv).
# 210311-11:27:51,319 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:51,634 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasink" in "/home/neuro/suvr/_subject_id_sub-OAS30004/datasink".
# 210311-11:27:51,953 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210311-11:27:52,14 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30004/sub-OAS30004_ses-test_acq-AV45_pet_t55-60_flirt.nii -> /home/neuro/coreg_frames/sub-OAS30004/sub-OAS30004_ses-test_acq-AV45_pet_t55-60_flirt.nii
# 210311-11:27:52,56 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30004/sub-OAS30004_ses-test_acq-AV45_pet_t55-60_flirt.mat -> /home/neuro/coreg_frames/sub-OAS30004/sub-OAS30004_ses-test_acq-AV45_pet_t55-60_flirt.mat
# 210311-11:27:52,197 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30004/sub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30004/sub-OAS30004_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:27:52,285 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30004/ssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30004/smoothed_sub-OAS30004_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:27:52,335 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30004/ssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -> /home/neuro/coreg_pet-t1/sub-OAS30004/smoothed_sub-OAS30004_ses-test_acq-AV45_pet_t50-60-avg_res.nii.gz
# 210311-11:27:52,501 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30004/ssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -> /home/neuro/coreg_pet-t1/sub-OAS30004/smoothed_sub-OAS30004_ses-test_acq-AV45_pet_t50-60-avg_aff.txt
# 210311-11:27:52,638 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30004/wsub-OAS30004_ses-test_T1w_flirt.nii -> /home/neuro/t1_mni/sub-OAS30004/wsub-OAS30004_ses-test_T1w_flirt.nii
# 210311-11:27:52,700 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30004/sub-OAS30004_ses-test_T1w_flirt_sn.mat -> /home/neuro/t1_mni/sub-OAS30004/sub-OAS30004_ses-test_T1w_flirt_sn.mat
# 210311-11:27:52,802 nipype.interface INFO:
# 	 sub: /home/neuro/pet_mni/_subject_id_sub-OAS30004/wssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -> /home/neuro/pet_mni/sub-OAS30004/mni_smoothed_sub-OAS30004_ses-test_acq-AV45_pet_t50-60-avg_res.nii
# 210311-11:27:52,889 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30004/wssub-OAS30004_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -> /home/neuro/suvr_result/sub-OAS30004/mni_smoothed_sub-OAS30004_ses-test_acq-AV45_pet_t50-60-avg_suvr.nii.gz
# 210311-11:27:52,917 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30004/result.csv -> /home/neuro/suvr_result/sub-OAS30004/result.csv
# 210311-11:27:53,18 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasink".
# 210311-11:27:53,303 nipype.workflow INFO:
# 	 [Job 31] Completed (suvr.datasink).
# 210311-11:27:53,328 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:54,343 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasource" in "/home/neuro/suvr/_subject_id_sub-OAS30002/datasource".
# 210311-11:27:54,466 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 210311-11:27:54,690 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasource".
# 210311-11:27:55,304 nipype.workflow INFO:
# 	 [Job 48] Completed (suvr.datasource).
# 210311-11:27:55,377 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_frames
# 210311-11:27:55,829 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.flt_coreg_template" in "/home/neuro/suvr/_subject_id_sub-OAS30002/flt_coreg_template".
# 210311-11:27:55,976 nipype.workflow INFO:
# 	 [Node] Running "flt_coreg_template" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/data/oasis_dataset/sub-OAS30002/ses-test/anat/sub-OAS30002_ses-test_T1w.nii.gz -ref /home/neuro/data/avg152T1.nii -out sub-OAS30002_ses-test_T1w_flirt.nii -omat sub-OAS30002_ses-test_T1w_flirt.mat -searchcost mutualinfo -dof 6
# 210311-11:27:57,346 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
#                        * suvr.flt_coreg_frames
# 210311-11:27:59,661 nipype.workflow INFO:
# 	 [Node] Finished "suvr.flt_coreg_frames".
# 210311-11:28:01,273 nipype.workflow INFO:
# 	 [Job 35] Completed (suvr.flt_coreg_frames).
# 210311-11:28:01,285 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:28:01,409 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_add_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30003/fmaths_add_frames".
# 210311-11:28:01,469 nipype.workflow INFO:
# 	 [Node] Running "fmaths_add_frames" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/data/oasis_dataset/sub-OAS30003/ses-test/pet/sub-OAS30003_ses-test_acq-AV45_pet_t50-55.nii.gz -add /home/neuro/suvr/_subject_id_sub-OAS30003/flt_coreg_frames/sub-OAS30003_ses-test_acq-AV45_pet_t55-60_flirt.nii /home/neuro/suvr/_subject_id_sub-OAS30003/fmaths_add_frames/sub-OAS30003_ses-test_acq-AV45_pet_t50-55_maths.nii
# 210311-11:28:02,711 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_add_frames".
# 210311-11:28:03,271 nipype.workflow INFO:
# 	 [Job 36] Completed (suvr.fmaths_add_frames).
# 210311-11:28:03,283 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:28:03,420 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_div_frames" in "/home/neuro/suvr/_subject_id_sub-OAS30003/fmaths_div_frames".
# 210311-11:28:03,468 nipype.workflow INFO:
# 	 [Node] Running "fmaths_div_frames" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/suvr/_subject_id_sub-OAS30003/fmaths_add_frames/sub-OAS30003_ses-test_acq-AV45_pet_t50-55_maths.nii -div 2.00000000 /home/neuro/suvr/_subject_id_sub-OAS30003/fmaths_div_frames/sub-OAS30003_ses-test_acq-AV45_pet_t50-55_maths_maths.nii
# 210311-11:28:04,337 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_div_frames".
# 210311-11:28:05,276 nipype.workflow INFO:
# 	 [Job 37] Completed (suvr.fmaths_div_frames).
# 210311-11:28:05,320 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:28:05,724 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_smooth" in "/home/neuro/suvr/_subject_id_sub-OAS30003/spm_smooth".
# 210311-11:28:05,909 nipype.workflow INFO:
# 	 [Node] Running "spm_smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 210311-11:28:07,276 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_smooth
#                        * suvr.flt_coreg_template
# 210311-11:28:45,133 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_smooth".
# 210311-11:28:45,336 nipype.workflow INFO:
# 	 [Job 38] Completed (suvr.spm_smooth).
# 210311-11:28:45,363 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.flt_coreg_template
# 210311-11:28:45,580 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.aladin_coreg_petmr" in "/home/neuro/suvr/_subject_id_sub-OAS30003/aladin_coreg_petmr".
# 210311-11:28:45,663 nipype.workflow INFO:
# 	 [Node] Running "aladin_coreg_petmr" ("nipype.interfaces.niftyreg.reg.RegAladin"), a CommandLine Interface with command:
# reg_aladin -aff ssub-OAS30003_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -flo /home/neuro/suvr/_subject_id_sub-OAS30003/spm_smooth/ssub-OAS30003_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -omp 1 -ref /home/neuro/suvr/_subject_id_sub-OAS30003/flt_coreg_template/sub-OAS30003_ses-test_T1w_flirt.nii -res ssub-OAS30003_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -rigOnly
# 210311-11:28:47,425 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.aladin_coreg_petmr
#                        * suvr.flt_coreg_template
# 210311-11:30:57,323 nipype.workflow INFO:
# 	 [Node] Finished "suvr.flt_coreg_template".
# 210311-11:30:57,514 nipype.workflow INFO:
# 	 [Job 49] Completed (suvr.flt_coreg_template).
# 210311-11:30:57,549 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.aladin_coreg_petmr
# 210311-11:30:57,726 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_anat" in "/home/neuro/suvr/_subject_id_sub-OAS30002/spm_norm_anat".
# 210311-11:30:57,800 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_anat" ("nipype.interfaces.spm.preprocess.Normalize")
# 210311-11:30:59,496 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
#                        * suvr.aladin_coreg_petmr
# 210311-11:31:24,490 nipype.workflow INFO:
# 	 [Node] Finished "suvr.aladin_coreg_petmr".
# 210311-11:31:25,529 nipype.workflow INFO:
# 	 [Job 39] Completed (suvr.aladin_coreg_petmr).
# 210311-11:31:25,556 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:31:25,758 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.gunzip_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30003/gunzip_pet".
# 210311-11:31:25,793 nipype.workflow INFO:
# 	 [Node] Running "gunzip_pet" ("nipype.algorithms.misc.Gunzip")
# 210311-11:31:26,20 nipype.workflow INFO:
# 	 [Node] Finished "suvr.gunzip_pet".
# 210311-11:31:27,530 nipype.workflow INFO:
# 	 [Job 40] Completed (suvr.gunzip_pet).
# 210311-11:31:27,546 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_anat
# 210311-11:31:27,678 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30003/spm_norm_pet".
# 210311-11:31:27,757 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_pet" ("nipype.interfaces.spm.preprocess.Normalize")
# 210311-11:31:29,530 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 1.35/1.75, Free processors: 0/2.
#                      Currently running:
#                        * suvr.spm_norm_pet
#                        * suvr.spm_norm_anat
# 210311-11:32:06,483 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_anat".
# 210311-11:32:07,65 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_pet".
# 210311-11:32:07,576 nipype.workflow INFO:
# 	 [Job 50] Completed (suvr.spm_norm_anat).
# 210311-11:32:07,581 nipype.workflow INFO:
# 	 [Job 41] Completed (suvr.spm_norm_pet).
# 210311-11:32:07,588 nipype.workflow INFO:
# ...
# 210311-11:35:05,707 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_tar_suvr" in "/home/neuro/suvr/_subject_id_sub-OAS30002/fstats_tar_suvr".210311-11:35:05,712 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_smooth" in "/home/neuro/suvr/_subject_id_sub-OAS30001/spm_smooth".
#
# 210311-11:35:05,729 nipype.workflow INFO:
# 	 [Node] Running "fstats_tar_suvr" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30002/fmaths_suvr_img/wssub-OAS30002_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -k /home/neuro/data/voi_ctx_2mm.nii -M 210311-11:35:05,732 nipype.workflow INFO:
# 	 [Node] Running "spm_smooth" ("nipype.interfaces.spm.preprocess.Smooth")
#
# 210311-11:35:05,923 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_tar_suvr".
# 210311-11:35:07,652 nipype.workflow INFO:
# 	 [Job 61] Completed (suvr.fstats_tar_suvr).
# 210311-11:35:07,657 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_smooth
# 210311-11:35:07,694 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.get_csv" in "/home/neuro/suvr/_subject_id_sub-OAS30002/get_csv".
# 210311-11:35:07,706 nipype.workflow INFO:
# 	 [Node] Running "get_csv" ("nipype.interfaces.utility.wrappers.Function")
# 210311-11:35:07,719 nipype.workflow INFO:
# 	 [Node] Finished "suvr.get_csv".
# 210311-11:35:09,654 nipype.workflow INFO:
# 	 [Job 62] Completed (suvr.get_csv).
# 210311-11:35:09,659 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_smooth
# 210311-11:35:09,702 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasink" in "/home/neuro/suvr/_subject_id_sub-OAS30002/datasink".
# 210311-11:35:09,727 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210311-11:35:09,738 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30002/sub-OAS30002_ses-test_acq-AV45_pet_t55-60_flirt.nii -> /home/neuro/coreg_frames/sub-OAS30002/sub-OAS30002_ses-test_acq-AV45_pet_t55-60_flirt.nii
# 210311-11:35:09,747 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30002/sub-OAS30002_ses-test_acq-AV45_pet_t55-60_flirt.mat -> /home/neuro/coreg_frames/sub-OAS30002/sub-OAS30002_ses-test_acq-AV45_pet_t55-60_flirt.mat
# 210311-11:35:09,761 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30002/sub-OAS30002_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30002/sub-OAS30002_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:35:09,770 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30002/ssub-OAS30002_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30002/smoothed_sub-OAS30002_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:35:09,780 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30002/ssub-OAS30002_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -> /home/neuro/coreg_pet-t1/sub-OAS30002/smoothed_sub-OAS30002_ses-test_acq-AV45_pet_t50-60-avg_res.nii.gz
# 210311-11:35:09,788 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30002/ssub-OAS30002_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -> /home/neuro/coreg_pet-t1/sub-OAS30002/smoothed_sub-OAS30002_ses-test_acq-AV45_pet_t50-60-avg_aff.txt
# 210311-11:35:09,798 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30002/wsub-OAS30002_ses-test_T1w_flirt.nii -> /home/neuro/t1_mni/sub-OAS30002/wsub-OAS30002_ses-test_T1w_flirt.nii
# 210311-11:35:09,815 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30002/sub-OAS30002_ses-test_T1w_flirt_sn.mat -> /home/neuro/t1_mni/sub-OAS30002/sub-OAS30002_ses-test_T1w_flirt_sn.mat
# 210311-11:35:09,825 nipype.interface INFO:
# 	 sub: /home/neuro/pet_mni/_subject_id_sub-OAS30002/wssub-OAS30002_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -> /home/neuro/pet_mni/sub-OAS30002/mni_smoothed_sub-OAS30002_ses-test_acq-AV45_pet_t50-60-avg_res.nii
# 210311-11:35:09,837 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30002/wssub-OAS30002_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -> /home/neuro/suvr_result/sub-OAS30002/mni_smoothed_sub-OAS30002_ses-test_acq-AV45_pet_t50-60-avg_suvr.nii.gz
# 210311-11:35:09,845 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30002/result.csv -> /home/neuro/suvr_result/sub-OAS30002/result.csv
# 210311-11:35:09,856 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasink".
# 210311-11:35:11,655 nipype.workflow INFO:
# 	 [Job 63] Completed (suvr.datasink).
# 210311-11:35:11,662 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_smooth
# 210311-11:35:17,997 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_smooth".
# 210311-11:35:19,661 nipype.workflow INFO:
# 	 [Job 70] Completed (suvr.spm_smooth).
# 210311-11:35:19,669 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:35:19,716 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.aladin_coreg_petmr" in "/home/neuro/suvr/_subject_id_sub-OAS30001/aladin_coreg_petmr".
# 210311-11:35:19,732 nipype.workflow INFO:
# 	 [Node] Running "aladin_coreg_petmr" ("nipype.interfaces.niftyreg.reg.RegAladin"), a CommandLine Interface with command:
# reg_aladin -aff ssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -flo /home/neuro/suvr/_subject_id_sub-OAS30001/spm_smooth/ssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -omp 1 -ref /home/neuro/suvr/_subject_id_sub-OAS30001/flt_coreg_template/sub-OAS30001_ses-test_T1w_flirt.nii -res ssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -rigOnly
# 210311-11:35:21,661 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.aladin_coreg_petmr
# 210311-11:36:12,89 nipype.workflow INFO:
# 	 [Node] Finished "suvr.aladin_coreg_petmr".
# 210311-11:36:13,666 nipype.workflow INFO:
# 	 [Job 71] Completed (suvr.aladin_coreg_petmr).
# 210311-11:36:13,673 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:36:13,729 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.gunzip_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30001/gunzip_pet".
# 210311-11:36:13,743 nipype.workflow INFO:
# 	 [Node] Running "gunzip_pet" ("nipype.algorithms.misc.Gunzip")
# 210311-11:36:13,807 nipype.workflow INFO:
# 	 [Node] Finished "suvr.gunzip_pet".
# 210311-11:36:15,666 nipype.workflow INFO:
# 	 [Job 72] Completed (suvr.gunzip_pet).
# 210311-11:36:15,671 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:36:15,727 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.spm_norm_pet" in "/home/neuro/suvr/_subject_id_sub-OAS30001/spm_norm_pet".
# 210311-11:36:15,750 nipype.workflow INFO:
# 	 [Node] Running "spm_norm_pet" ("nipype.interfaces.spm.preprocess.Normalize")
# 210311-11:36:17,667 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 1.55/1.75, Free processors: 1/2.
#                      Currently running:
#                        * suvr.spm_norm_pet
# 210311-11:36:27,527 nipype.workflow INFO:
# 	 [Node] Finished "suvr.spm_norm_pet".
# 210311-11:36:27,647 nipype.workflow INFO:
# 	 [Job 73] Completed (suvr.spm_norm_pet).
# 210311-11:36:27,658 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:36:27,718 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_tar_uptake" in "/home/neuro/suvr/_subject_id_sub-OAS30001/fstats_tar_uptake".210311-11:36:27,721 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_ref_uptake" in "/home/neuro/suvr/_subject_id_sub-OAS30001/fstats_ref_uptake".
# 210311-11:36:27,732 nipype.workflow INFO:
# 	 [Node] Running "fstats_ref_uptake" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30001/spm_norm_pet/wssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -k /home/neuro/data/voi_WhlCbl_2mm.nii -M
#
# 210311-11:36:27,751 nipype.workflow INFO:
# 	 [Node] Running "fstats_tar_uptake" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30001/spm_norm_pet/wssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -k /home/neuro/data/voi_ctx_2mm.nii -M
# 210311-11:36:27,934 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_ref_uptake".
# 210311-11:36:27,950 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_tar_uptake".
# 210311-11:36:29,640 nipype.workflow INFO:
# 	 [Job 74] Completed (suvr.fstats_tar_uptake).
# 210311-11:36:29,648 nipype.workflow INFO:
# 	 [Job 75] Completed (suvr.fstats_ref_uptake).
# 210311-11:36:29,654 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:36:29,701 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fmaths_suvr_img" in "/home/neuro/suvr/_subject_id_sub-OAS30001/fmaths_suvr_img".
# 210311-11:36:29,719 nipype.workflow INFO:
# 	 [Node] Running "fmaths_suvr_img" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /home/neuro/suvr/_subject_id_sub-OAS30001/spm_norm_pet/wssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -div 4831.17368300 /home/neuro/suvr/_subject_id_sub-OAS30001/fmaths_suvr_img/wssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz
# 210311-11:36:30,57 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fmaths_suvr_img".
# 210311-11:36:31,638 nipype.workflow INFO:
# 	 [Job 76] Completed (suvr.fmaths_suvr_img).
# 210311-11:36:31,644 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:36:31,691 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.fstats_tar_suvr" in "/home/neuro/suvr/_subject_id_sub-OAS30001/fstats_tar_suvr".
# 210311-11:36:31,706 nipype.workflow INFO:
# 	 [Node] Running "fstats_tar_suvr" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /home/neuro/suvr/_subject_id_sub-OAS30001/fmaths_suvr_img/wssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -k /home/neuro/data/voi_ctx_2mm.nii -M
# 210311-11:36:31,894 nipype.workflow INFO:
# 	 [Node] Finished "suvr.fstats_tar_suvr".
# 210311-11:36:33,640 nipype.workflow INFO:
# 	 [Job 77] Completed (suvr.fstats_tar_suvr).
# 210311-11:36:33,650 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:36:33,693 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.get_csv" in "/home/neuro/suvr/_subject_id_sub-OAS30001/get_csv".
# 210311-11:36:33,705 nipype.workflow INFO:
# 	 [Node] Running "get_csv" ("nipype.interfaces.utility.wrappers.Function")
# 210311-11:36:33,720 nipype.workflow INFO:
# 	 [Node] Finished "suvr.get_csv".
# 210311-11:36:35,641 nipype.workflow INFO:
# 	 [Job 78] Completed (suvr.get_csv).
# 210311-11:36:35,652 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# 210311-11:36:35,698 nipype.workflow INFO:
# 	 [Node] Setting-up "suvr.datasink" in "/home/neuro/suvr/_subject_id_sub-OAS30001/datasink".
# 210311-11:36:35,718 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210311-11:36:35,727 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30001/sub-OAS30001_ses-test_acq-AV45_pet_t55-60_flirt.nii -> /home/neuro/coreg_frames/sub-OAS30001/sub-OAS30001_ses-test_acq-AV45_pet_t55-60_flirt.nii
# 210311-11:36:35,733 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_frames/_subject_id_sub-OAS30001/sub-OAS30001_ses-test_acq-AV45_pet_t55-60_flirt.mat -> /home/neuro/coreg_frames/sub-OAS30001/sub-OAS30001_ses-test_acq-AV45_pet_t55-60_flirt.mat
# 210311-11:36:35,743 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30001/sub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30001/sub-OAS30001_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:36:35,752 nipype.interface INFO:
# 	 sub: /home/neuro/pet_t5060/_subject_id_sub-OAS30001/ssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths.nii -> /home/neuro/pet_t5060/sub-OAS30001/smoothed_sub-OAS30001_ses-test_acq-AV45_pet_t50-60-avg.nii
# 210311-11:36:35,762 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30001/ssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii.gz -> /home/neuro/coreg_pet-t1/sub-OAS30001/smoothed_sub-OAS30001_ses-test_acq-AV45_pet_t50-60-avg_res.nii.gz
# 210311-11:36:35,773 nipype.interface INFO:
# 	 sub: /home/neuro/coreg_pet-t1/_subject_id_sub-OAS30001/ssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_aff.txt -> /home/neuro/coreg_pet-t1/sub-OAS30001/smoothed_sub-OAS30001_ses-test_acq-AV45_pet_t50-60-avg_aff.txt
# 210311-11:36:35,782 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30001/wsub-OAS30001_ses-test_T1w_flirt.nii -> /home/neuro/t1_mni/sub-OAS30001/wsub-OAS30001_ses-test_T1w_flirt.nii
# 210311-11:36:35,792 nipype.interface INFO:
# 	 sub: /home/neuro/t1_mni/_subject_id_sub-OAS30001/sub-OAS30001_ses-test_T1w_flirt_sn.mat -> /home/neuro/t1_mni/sub-OAS30001/sub-OAS30001_ses-test_T1w_flirt_sn.mat
# 210311-11:36:35,802 nipype.interface INFO:
# 	 sub: /home/neuro/pet_mni/_subject_id_sub-OAS30001/wssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res.nii -> /home/neuro/pet_mni/sub-OAS30001/mni_smoothed_sub-OAS30001_ses-test_acq-AV45_pet_t50-60-avg_res.nii
# 210311-11:36:35,811 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30001/wssub-OAS30001_ses-test_acq-AV45_pet_t50-55_maths_maths_res_maths.nii.gz -> /home/neuro/suvr_result/sub-OAS30001/mni_smoothed_sub-OAS30001_ses-test_acq-AV45_pet_t50-60-avg_suvr.nii.gz
# 210311-11:36:35,823 nipype.interface INFO:
# 	 sub: /home/neuro/suvr_result/_subject_id_sub-OAS30001/result.csv -> /home/neuro/suvr_result/sub-OAS30001/result.csv
# 210311-11:36:35,841 nipype.workflow INFO:
# 	 [Node] Finished "suvr.datasink".
# 210311-11:36:37,642 nipype.workflow INFO:
# 	 [Job 79] Completed (suvr.datasink).
# 210311-11:36:37,651 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 1.75/1.75, Free processors: 2/2.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-11-de67e654eb25> in <module>()
#       1 suvr_pipeline.run(plugin='MultiProc') #run in parallel
# ----> 2 suvr_pipeline.write_graph(dotfilename='/home/neuro/output/results/workflow_graph.dot')
#
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nipype/pipeline/engine/workflows.py in write_graph(self, dotfilename, graph2use, format, simple_form)
#     444             else:
#     445                 base_dir = os.getcwd()
# --> 446         os.makedirs(base_dir, exist_ok=True)
#     447         if graph2use in ["hierarchical", "colored"]:
#     448             if self.name[:1].isdigit():  # these graphs break if int
#
# /opt/miniconda-latest/envs/neuro/lib/python3.6/os.py in makedirs(name, mode, exist_ok)
#     218             return
#     219     try:
# --> 220         mkdir(name, mode)
#     221     except OSError:
#     222         # Cannot rely on checking for EEXIST, since the operating system
#
# PermissionError: [Errno 13] Permission denied: '/home/neuro/output/results'

# %% [markdown]
# ## Summary
#
# ### Interface:
# specific software (e.g. FSL, SPM, FreeSurfer, ANTs ...) are wrapped in interfaces, within a node instances of an interface can be run
#
# ### Node:
# Holds an interfact, you can give it a name, a takes input and gives output
#
# ### Workflow:
# Connected series of nodes, can be run parallel and or sequential
#
# ### Pipeline:
# Pretty much the same as a workflow
#
# ### Modules:
# For each interface the according modules have to be imported in the usual pythonic manner
#
# ### Crash Files:
#
# In bash command line:
# nipypecli crash path/to/crash/file.pklz
